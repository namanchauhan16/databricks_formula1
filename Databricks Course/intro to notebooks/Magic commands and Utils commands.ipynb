# %%
# %fs
ls /

# %%
# %sh
ps

# %%
# %pip list

# %%
items = dbutils.fs.ls("/databricks-datasets/")

# %%
folder_count = sum(1 for item in items if item.isDir())
file_count = sum(1 for item in items if not item.isDir())
display([(f"Folders: {folder_count}", f"Files: {file_count}")])
